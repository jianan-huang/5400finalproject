# %%
import model_accuracy

# %%
# %run model_accuracy.py
# Out:
# --- Dataset Information ---
# Total number of rows: 14250
# Number of unique companies: 30
# Date range: 2023-01-03 to 2024-11-20
#
# Available columns:
# - company
# - date
# - close_price
# - daily_return
# - volatility
# - moving_avg_7
# - moving_avg_30
# - vader_daily_sentiment_score
# - finbert_daily_sentiment_score
# - news_count
# - vader_sentiment_std
# - finbert_sentiment_std
# - vader_daily_sentiment_score_lag1
# - finbert_daily_sentiment_score_lag1
#
# Selected Features:
# - daily_return
# - volatility
# - vader_daily_sentiment_score
# - finbert_daily_sentiment_score
# - moving_avg_7
# - ema_7
# - moving_avg_30
# - ema_30
#
# Logistic Regression Model Performance:
# Accuracy: 0.64
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70        20
#            1       0.54      0.54      0.54        13
#
#     accuracy                           0.64        33
#    macro avg       0.62      0.62      0.62        33
# ...
